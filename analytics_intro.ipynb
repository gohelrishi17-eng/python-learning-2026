# %%
print("My Name is Rishi Gohel")
print("My favorite game is Free Fire")
# Out:
# My Name is Rishi Gohel
# My favorite game is Free Fire

# %%
import datetime
print(datetime.datetime.now().year)
# Out:
# 2026
